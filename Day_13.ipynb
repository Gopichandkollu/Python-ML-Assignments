# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopichandkollu/Python-ML-Assignments/blob/main/Day_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"/content/Day_13_Pharma_data.csv")
df
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# ...

# %%
df.isnull().sum()
# Out:
# Product_ID         0
# Product_Name       0
# Region             0
# Marketing_Spend    0
# Sales              0
# Effectiveness      0
# Side_Effects       0
# Age_Group          0
# Trial_Period       0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# ...

# %%
total_sales_by_region = df.groupby('Region')['Sales'].sum()
total_sales_by_region.plot(kind='bar')
plt.title('Total Sales per Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.scatter(df['Marketing_Spend'], df['Sales'])
plt.title('Relationship between Marketing Spend and Sales')
plt.xlabel('Marketing Spend')
plt.ylabel('Sales')
plt.show()

# %%
sns.boxplot(x='Age_Group', y='Effectiveness', data=df)
plt.title('Drug Effectiveness across Different Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Effectiveness')
plt.show()

# %%
sns.lineplot(x='Trial_Period', y='Sales', hue='Product_Name', data=df)
plt.title('Sales Trend for Each Product over Different Trial Periods')
plt.xlabel('Trial Period')
plt.ylabel('Sales')
plt.show()

# %%
correlation_matrix = df[['Sales', 'Marketing_Spend', 'Effectiveness']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation between Sales, Marketing Spend, and Effectiveness')
plt.show()
